# %% [markdown]
# <a href="https://colab.research.google.com/github/https-deeplearning-ai/tensorflow-1-public/blob/master/C3/W2/ungraded_labs/C3_W2_Lab_2_sarcasm_classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ungraded Lab: Training a binary classifier with the Sarcasm Dataset
#
# In this lab, you will revisit the [News Headlines Dataset for Sarcasm Detection](https://www.kaggle.com/rmisra/news-headlines-dataset-for-sarcasm-detection/home) from last week and proceed to build a train a model on it. The steps will be very similar to the previous lab with IMDB Reviews with just some minor modifications. You can tweak the hyperparameters and see how it affects the results. Let's begin!

# %% [markdown]
# ## Download the dataset
#
# You will first download the JSON file, load it into your workspace and put the sentences and labels into lists.

# %%
# Download the dataset
# !wget https://storage.googleapis.com/tensorflow-1-public/course3/sarcasm.json
# Out:
# --2024-03-19 21:36:26--  https://storage.googleapis.com/tensorflow-1-public/course3/sarcasm.json
# storage.googleapis.com (storage.googleapis.com) 해석 중... 34.64.4.123, 34.64.4.59, 34.64.4.27, ...
# 다음으로 연결 중: storage.googleapis.com (storage.googleapis.com)|34.64.4.123|:443... 연결했습니다.
# HTTP 요청을 보냈습니다. 응답 기다리는 중... 200 OK
# 길이: 5643545 (5.4M) [application/json]
# 저장 위치: `sarcasm.json'
#
# sarcasm.json        100%[===================>]   5.38M  5.87MB/s    /  0.9s
#
# 2024-03-19 21:36:28 (5.87 MB/s) - `sarcasm.json' 저장함 [5643545/5643545]

# %%
import json

# Load the JSON file
with open("./sarcasm.json", 'r') as f:
    datastore = json.load(f)

# Initialize the lists
sentences = []
labels = []

# Collect sentences and labels into the lists
for item in datastore:
    sentences.append(item['headline'])
    labels.append(item['is_sarcastic'])

# %% [markdown]
# ## Hyperparameters
#
# We placed the hyperparameters in the cell below so you can easily tweak it later:

# %%
# Number of examples to use for training
training_size = 20000

# Vocabulary size of the tokenizer
vocab_size = 10000

# Maximum length of the padded sequences
max_length = 32

# Output dimensions of the Embedding layer
embedding_dim = 16

# %% [markdown]
# ## Split the dataset
#
# Next, you will generate your train and test datasets. You will use the `training_size` value you set above to slice the `sentences` and `labels` lists into two sublists: one fore training and another for testing.

# %%
# Split the sentences
training_sentences = sentences[0:training_size]
testing_sentences = sentences[training_size:]

# Split the labels
training_labels = labels[0:training_size]
testing_labels = labels[training_size:]

# %%
len(training_labels)
# Out:
# 20000

# %%
len(testing_labels)
# Out:
# 6709

# %% [markdown]
# ## Preprocessing the train and test sets
#
# Now you can preprocess the text and labels so it can be consumed by the model. You use the `Tokenizer` class to create the vocabulary and the `pad_sequences` method to generate padded token sequences. You will also need to set the labels to a numpy array so it can be a valid data type for `model.fit()`.

# %%
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Parameters for padding and OOV tokens
trunc_type='post'
padding_type='post'
oov_tok = "<OOV>"

# Initialize the Tokenizer class
tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_tok)

# Generate the word index dictionary
tokenizer.fit_on_texts(training_sentences)
word_index = tokenizer.word_index

# Generate and pad the training sequences
training_sequences = tokenizer.texts_to_sequences(training_sentences)
training_padded = pad_sequences(training_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

# Generate and pad the testing sequences
testing_sequences = tokenizer.texts_to_sequences(testing_sentences)
testing_padded = pad_sequences(testing_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

# Convert the labels lists into numpy arrays
training_labels = np.array(training_labels)
testing_labels = np.array(testing_labels)

# %% [markdown]
# ## Build and Compile the Model
#
# Next, you will build the model. The architecture is similar to the previous lab but you will use a [GlobalAveragePooling1D](https://www.tensorflow.org/api_docs/python/tf/keras/layers/GlobalAveragePooling1D) layer instead of `Flatten` after the Embedding. This adds the task of averaging over the sequence dimension before connecting to the dense layers. See a short demo of how this works using the snippet below. Notice that it gets the average over 3 arrays (i.e. `(10 + 1 + 1) / 3` and `(2 + 3 + 1) / 3` to arrive at the final output.

# %%
import tensorflow as tf

# Initialize a GlobalAveragePooling1D (GAP1D) layer
gap1d_layer = tf.keras.layers.GlobalAveragePooling1D()

# Define sample array
sample_array = np.array([[[10,2],[1,3],[1,1]]])

# Print shape and contents of sample array
print(f'shape of sample_array = {sample_array.shape}')
print(f'sample array: {sample_array}')

# Pass the sample array to the GAP1D layer
output = gap1d_layer(sample_array)

# Print shape and contents of the GAP1D output array
print(f'output shape of gap1d_layer: {output.shape}')
print(f'output array of gap1d_layer: {output.numpy()}')
# Out:
# shape of sample_array = (1, 3, 2)
# sample array: [[[10  2]
#   [ 1  3]
#   [ 1  1]]]
# output shape of gap1d_layer: (1, 2)
# output array of gap1d_layer: [[4 2]]

# %% [markdown]
# This added computation reduces the dimensionality of the model as compared to using `Flatten()` and thus, the number of training parameters will also decrease. See the output of `model.summary()` below and see how it compares if you swap out the pooling layer with a simple `Flatten()`.

# %%
# Build the model
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(24, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# Print the model summary
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_8 (Embedding)     (None, 32, 16)            160000
#
#  global_average_pooling1d_1  (None, 16)                0
#  5 (GlobalAveragePooling1D)
#
#  dense_16 (Dense)            (None, 24)                408
#
#  dense_17 (Dense)            (None, 1)                 25
#
# =================================================================
# Total params: 160433 (626.69 KB)
# Trainable params: 160433 (626.69 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# You will use the same loss, optimizer, and metrics from the previous lab.

# %%
# Compile the model
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %% [markdown]
# ## Train the Model
#
# Now you will feed in the prepared datasets to train the model. If you used the default hyperparameters, you will get around 99% training accuracy and 80% validation accuracy.
#
# *Tip: You can set the `verbose` parameter of `model.fit()` to `2` to indicate that you want to print just the results per epoch. Setting it to `1` (default) displays a progress bar per epoch, while `0` silences all displays. It doesn't matter much in this Colab but when working in a production environment, you may want to set this to `2` as recommended in the [documentation](https://keras.io/api/models/model_training_apis/#fit-method).*

# %%
num_epochs = 30

# Train the model
history = model.fit(training_padded, training_labels, epochs=num_epochs, validation_data=(testing_padded, testing_labels), verbose=2)
# Out:
# Epoch 1/30
# 625/625 - 1s - loss: 0.5703 - accuracy: 0.6937 - val_loss: 0.4028 - val_accuracy: 0.8377 - 1s/epoch - 2ms/step
# Epoch 2/30
# 625/625 - 1s - loss: 0.3165 - accuracy: 0.8727 - val_loss: 0.3506 - val_accuracy: 0.8465 - 618ms/epoch - 989us/step
# Epoch 3/30
# 625/625 - 1s - loss: 0.2355 - accuracy: 0.9067 - val_loss: 0.3657 - val_accuracy: 0.8402 - 583ms/epoch - 934us/step
# Epoch 4/30
# 625/625 - 1s - loss: 0.1910 - accuracy: 0.9266 - val_loss: 0.3608 - val_accuracy: 0.8544 - 638ms/epoch - 1ms/step
# Epoch 5/30
# 625/625 - 1s - loss: 0.1579 - accuracy: 0.9417 - val_loss: 0.4083 - val_accuracy: 0.8404 - 591ms/epoch - 945us/step
# Epoch 6/30
# 625/625 - 1s - loss: 0.1339 - accuracy: 0.9514 - val_loss: 0.4244 - val_accuracy: 0.8450 - 695ms/epoch - 1ms/step
# Epoch 7/30
# 625/625 - 1s - loss: 0.1140 - accuracy: 0.9607 - val_loss: 0.4620 - val_accuracy: 0.8419 - 569ms/epoch - 910us/step
# Epoch 8/30
# 625/625 - 1s - loss: 0.0982 - accuracy: 0.9664 - val_loss: 0.5081 - val_accuracy: 0.8423 - 631ms/epoch - 1ms/step
# Epoch 9/30
# 625/625 - 1s - loss: 0.0853 - accuracy: 0.9722 - val_loss: 0.5570 - val_accuracy: 0.8343 - 609ms/epoch - 974us/step
# Epoch 10/30
# 625/625 - 1s - loss: 0.0748 - accuracy: 0.9756 - val_loss: 0.6015 - val_accuracy: 0.8302 - 635ms/epoch - 1ms/step
# Epoch 11/30
# 625/625 - 1s - loss: 0.0646 - accuracy: 0.9797 - val_loss: 0.6517 - val_accuracy: 0.8280 - 650ms/epoch - 1ms/step
# Epoch 12/30
# 625/625 - 1s - loss: 0.0577 - accuracy: 0.9821 - val_loss: 0.7104 - val_accuracy: 0.8244 - 622ms/epoch - 995us/step
# Epoch 13/30
# 625/625 - 1s - loss: 0.0495 - accuracy: 0.9854 - val_loss: 0.7771 - val_accuracy: 0.8232 - 594ms/epoch - 951us/step
# Epoch 14/30
# 625/625 - 1s - loss: 0.0432 - accuracy: 0.9876 - val_loss: 0.8216 - val_accuracy: 0.8201 - 600ms/epoch - 961us/step
# Epoch 15/30
# 625/625 - 1s - loss: 0.0378 - accuracy: 0.9902 - val_loss: 0.8835 - val_accuracy: 0.8179 - 612ms/epoch - 979us/step
# Epoch 16/30
# 625/625 - 1s - loss: 0.0329 - accuracy: 0.9908 - val_loss: 0.9594 - val_accuracy: 0.8182 - 578ms/epoch - 925us/step
# Epoch 17/30
# 625/625 - 1s - loss: 0.0295 - accuracy: 0.9916 - val_loss: 1.0129 - val_accuracy: 0.8134 - 595ms/epoch - 952us/step
# Epoch 18/30
# 625/625 - 1s - loss: 0.0267 - accuracy: 0.9924 - val_loss: 1.0710 - val_accuracy: 0.8113 - 588ms/epoch - 941us/step
# Epoch 19/30
# 625/625 - 1s - loss: 0.0239 - accuracy: 0.9935 - val_loss: 1.1470 - val_accuracy: 0.8131 - 585ms/epoch - 936us/step
# Epoch 20/30
# 625/625 - 1s - loss: 0.0204 - accuracy: 0.9938 - val_loss: 1.2036 - val_accuracy: 0.8114 - 602ms/epoch - 964us/step
# Epoch 21/30
# 625/625 - 1s - loss: 0.0184 - accuracy: 0.9946 - val_loss: 1.2602 - val_accuracy: 0.8095 - 597ms/epoch - 955us/step
# Epoch 22/30
# 625/625 - 1s - loss: 0.0167 - accuracy: 0.9954 - val_loss: 1.3469 - val_accuracy: 0.8067 - 582ms/epoch - 930us/step
# Epoch 23/30
# 625/625 - 1s - loss: 0.0142 - accuracy: 0.9963 - val_loss: 1.4010 - val_accuracy: 0.8073 - 564ms/epoch - 903us/step
# Epoch 24/30
# 625/625 - 1s - loss: 0.0134 - accuracy: 0.9963 - val_loss: 1.4826 - val_accuracy: 0.8041 - 610ms/epoch - 975us/step
# Epoch 25/30
# 625/625 - 1s - loss: 0.0125 - accuracy: 0.9964 - val_loss: 1.4870 - val_accuracy: 0.8049 - 621ms/epoch - 994us/step
# Epoch 26/30
# 625/625 - 1s - loss: 0.0116 - accuracy: 0.9966 - val_loss: 1.5825 - val_accuracy: 0.8031 - 618ms/epoch - 989us/step
# Epoch 27/30
# 625/625 - 1s - loss: 0.0111 - accuracy: 0.9974 - val_loss: 1.6380 - val_accuracy: 0.8055 - 611ms/epoch - 978us/step
# Epoch 28/30
# 625/625 - 1s - loss: 0.0100 - accuracy: 0.9973 - val_loss: 1.6341 - val_accuracy: 0.7989 - 581ms/epoch - 930us/step
# Epoch 29/30
# 625/625 - 1s - loss: 0.0090 - accuracy: 0.9979 - val_loss: 1.6974 - val_accuracy: 0.8034 - 561ms/epoch - 898us/step
# Epoch 30/30
# 625/625 - 1s - loss: 0.0086 - accuracy: 0.9977 - val_loss: 1.8324 - val_accuracy: 0.8016 - 582ms/epoch - 931us/step

# %% [markdown]
# ## Visualize the Results
#
# You can use the cell below to plot the training results. You may notice some overfitting because your validation accuracy is slowly dropping while the training accuracy is still going up. See if you can improve it by tweaking the hyperparameters. Some example values are shown in the lectures.

# %%
import matplotlib.pyplot as plt

# Plot utility
def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()
  
# Plot the accuracy and loss
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

# %%
num_epochs = 15

# Train the model
history = model.fit(training_padded, training_labels, epochs=num_epochs, validation_data=(testing_padded, testing_labels), verbose=2)
# Out:
# Epoch 1/15
# 625/625 - 1s - loss: 0.5704 - accuracy: 0.6974 - val_loss: 0.4040 - val_accuracy: 0.8354 - 956ms/epoch - 2ms/step
# Epoch 2/15
# 625/625 - 1s - loss: 0.3194 - accuracy: 0.8705 - val_loss: 0.3456 - val_accuracy: 0.8533 - 603ms/epoch - 965us/step
# Epoch 3/15
# 625/625 - 1s - loss: 0.2406 - accuracy: 0.9058 - val_loss: 0.3414 - val_accuracy: 0.8536 - 620ms/epoch - 992us/step
# Epoch 4/15
# 625/625 - 1s - loss: 0.1943 - accuracy: 0.9258 - val_loss: 0.3571 - val_accuracy: 0.8518 - 610ms/epoch - 975us/step
# Epoch 5/15
# 625/625 - 1s - loss: 0.1618 - accuracy: 0.9406 - val_loss: 0.3789 - val_accuracy: 0.8508 - 604ms/epoch - 967us/step
# Epoch 6/15
# 625/625 - 1s - loss: 0.1384 - accuracy: 0.9493 - val_loss: 0.4123 - val_accuracy: 0.8484 - 636ms/epoch - 1ms/step
# Epoch 7/15
# 625/625 - 1s - loss: 0.1179 - accuracy: 0.9592 - val_loss: 0.4453 - val_accuracy: 0.8432 - 613ms/epoch - 981us/step
# Epoch 8/15
# 625/625 - 1s - loss: 0.1027 - accuracy: 0.9658 - val_loss: 0.4807 - val_accuracy: 0.8407 - 572ms/epoch - 916us/step
# Epoch 9/15
# 625/625 - 1s - loss: 0.0896 - accuracy: 0.9692 - val_loss: 0.5219 - val_accuracy: 0.8365 - 583ms/epoch - 932us/step
# Epoch 10/15
# 625/625 - 1s - loss: 0.0781 - accuracy: 0.9746 - val_loss: 0.5691 - val_accuracy: 0.8325 - 549ms/epoch - 878us/step
# Epoch 11/15
# 625/625 - 1s - loss: 0.0685 - accuracy: 0.9772 - val_loss: 0.6256 - val_accuracy: 0.8280 - 557ms/epoch - 891us/step
# Epoch 12/15
# 625/625 - 1s - loss: 0.0595 - accuracy: 0.9819 - val_loss: 0.6700 - val_accuracy: 0.8261 - 557ms/epoch - 891us/step
# Epoch 13/15
# 625/625 - 1s - loss: 0.0529 - accuracy: 0.9851 - val_loss: 0.7253 - val_accuracy: 0.8244 - 560ms/epoch - 896us/step
# Epoch 14/15
# 625/625 - 1s - loss: 0.0472 - accuracy: 0.9862 - val_loss: 0.7783 - val_accuracy: 0.8219 - 548ms/epoch - 877us/step
# Epoch 15/15
# 625/625 - 1s - loss: 0.0399 - accuracy: 0.9886 - val_loss: 0.8339 - val_accuracy: 0.8193 - 554ms/epoch - 887us/step

# %%
import matplotlib.pyplot as plt

# Plot utility
def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()
  
# Plot the accuracy and loss
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

# %%
from tensorflow.keras import regularizers

# %%
# Build the model
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(8, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# Print the model summary
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_9 (Embedding)     (None, 32, 16)            160000
#
#  global_average_pooling1d_1  (None, 16)                0
#  6 (GlobalAveragePooling1D)
#
#  dense_18 (Dense)            (None, 8)                 136
#
#  dense_19 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 160145 (625.57 KB)
# Trainable params: 160145 (625.57 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
num_epochs = 5

# Train the model
history = model.fit(training_padded, training_labels, epochs=num_epochs, validation_data=(testing_padded, testing_labels), verbose=2)
# Out:
# Epoch 1/5
# 625/625 - 1s - loss: 0.6282 - accuracy: 0.6532 - val_loss: 0.5091 - val_accuracy: 0.8240 - 947ms/epoch - 2ms/step
# Epoch 2/5
# 625/625 - 1s - loss: 0.4165 - accuracy: 0.8624 - val_loss: 0.4121 - val_accuracy: 0.8484 - 614ms/epoch - 982us/step
# Epoch 3/5
# 625/625 - 1s - loss: 0.3316 - accuracy: 0.8936 - val_loss: 0.3899 - val_accuracy: 0.8526 - 646ms/epoch - 1ms/step
# Epoch 4/5
# 625/625 - 1s - loss: 0.2856 - accuracy: 0.9111 - val_loss: 0.3823 - val_accuracy: 0.8575 - 584ms/epoch - 935us/step
# Epoch 5/5
# 625/625 - 1s - loss: 0.2538 - accuracy: 0.9247 - val_loss: 0.3802 - val_accuracy: 0.8559 - 630ms/epoch - 1ms/step

# %%
import matplotlib.pyplot as plt

# Plot utility
def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()
  
# Plot the accuracy and loss
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

# %% [markdown]
# ## Visualize Word Embeddings
#
# As before, you can visualize the final weights of the embeddings using the [Tensorflow Embedding Projector](https://projector.tensorflow.org/).

# %%
# Get the index-word dictionary
reverse_word_index = tokenizer.index_word

# Get the embedding layer from the model (i.e. first layer)
embedding_layer = model.layers[0]

# Get the weights of the embedding layer
embedding_weights = embedding_layer.get_weights()[0]

# Print the shape. Expected is (vocab_size, embedding_dim)
print(embedding_weights.shape)
# Out:
# (10000, 16)

# %%
import io

# Open writeable files
out_v = io.open('vecs.tsv', 'w', encoding='utf-8')
out_m = io.open('meta.tsv', 'w', encoding='utf-8')

# Initialize the loop. Start counting at `1` because `0` is just for the padding
for word_num in range(1, vocab_size):

  # Get the word associated at the current index
  word_name = reverse_word_index[word_num]

  # Get the embedding weights associated with the current index
  word_embedding = embedding_weights[word_num]

  # Write the word name
  out_m.write(word_name + "\n")

  # Write the word embedding
  out_v.write('\t'.join([str(x) for x in word_embedding]) + "\n")

# Close the files
out_v.close()
out_m.close()

# %%
# Import files utilities in Colab
try:
  from google.colab import files
except ImportError:
  pass

# Download the files
else:
  files.download('vecs.tsv')
  files.download('meta.tsv')

# %% [markdown]
# ## Wrap Up
#
# In this lab, you were able to build a binary classifier to detect sarcasm. You saw some overfitting in the initial attempt and hopefully, you were able to arrive at a better set of hyperparameters.
#
# So far, you've been tokenizing datasets from scratch and you're treating the vocab size as a hyperparameter. Furthermore, you're tokenizing the texts by building a vocabulary of full words. In the next lab, you will make use of a pre-tokenized dataset that uses a vocabulary of *subwords*. For instance, instead of having a uniqe token for the word `Tensorflow`, it will instead have a token each for `Ten`, `sor`, and `flow`. You will see the motivation and implications of having this design in the next exercise. See you there!
